# %%
import pandas as pd
import matplotlib as mpl

df_arbolado = pd.read_csv("./datos/CABA-arbolado-en-espacios-verdes.csv")
df_arbolado
# Out:
#                           long                      lat  id_arbol  altura_tot  \
# 0             -584.775.636.069         -346.450.145.297         1           6
# 1             -584.775.587.043  -34.645.046.711.599.900         2           6
# 2      -58.477.550.640.699.900         -346.450.909.731         3           6
# 3             -584.781.292.923         -346.445.670.766         4          17
# 4             -584.781.211.175         -346.445.979.068         5          17
# ...                        ...                      ...       ...         ...
# 51497         -585.057.516.455         -345.629.976.776     51725          15
# 51498          -58.507.110.997         -345.658.433.331     51726          13
# 51499         -584.757.209.837         -345.651.916.682     51727          11
# 51500         -585.070.262.347         -345.656.699.253     51728           5
# 51501         -585.068.743.702         -345.653.342.811     51729          10
#
# ...

# %%
df_espacio_verde = pd.read_csv("./datos/espacio_verde_publico.csv")
df_espacio_verde
# Out:
#                                                     WKT  \
# 0     MULTIPOLYGON (((-58.4453556017045 -34.57924873...
# 1     MULTIPOLYGON (((-58.4448074253007 -34.57987067...
# 2     MULTIPOLYGON (((-58.4382360541145 -34.54616199...
# 3     MULTIPOLYGON (((-58.4552876770316 -34.56223232...
# 4     MULTIPOLYGON (((-58.4371387094279 -34.55314301...
# ...                                                 ...
# 1760  MULTIPOLYGON (((-58.5152362978946 -34.59610662...
# 1761  MULTIPOLYGON (((-58.4552015308575 -34.54615792...
# 1762  MULTIPOLYGON (((-58.5067142089469 -34.65989310...
# 1763  MULTIPOLYGON (((-58.5081497617616 -34.65844038...
# 1764  MULTIPOLYGON (((-58.5237170510223 -34.65573868...
#
#                                                  nombre  \
# 0                              Escuela Scalabrini Ortiz
# 1                              Polideportivo Colegiales
# 2                                                   NaN
# 3                                Plaza Rafael Hernández
# ...
